# %% [markdown]
# # Dataset

# %% [markdown]
# ## Import Library

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")
import os
import glob

# pytorch
import torch
from torch import optim
from torch.autograd import Variable,gradcheck
from torch.utils.data import DataLoader
import torch.nn as nn

# sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# others
import numpy as np
import pandas as pd
import pdb
import sys
sys.path.append("../")
from all_models import seed_everything,MTNNConv_PressureVelocity,DNN
import evaluation_and_visualization as ev_viz

# %% [markdown]
# # Load Data

# %%
TRAINPERCENTAGE=0.55
DATASETNAME="../../../../datasets/evaluation_data/AllData_with_Pressure_And_Velocity_Samples_case1/AllData_PRESSURE_and_VELOCITY_10_SAMPLES_All_RE_SF_Groups_TRAINPERCENTAGE_{}_With_Output_Mask_".format(TRAINPERCENTAGE)

exists = os.path.isfile(DATASETNAME+"trainX.npy")
if exists:
    X_train=np.load(DATASETNAME+"trainX.npy")
    y_train=np.load(DATASETNAME+"trainY.npy")
    X_val=np.load(DATASETNAME+"valX.npy")
    y_val=np.load(DATASETNAME+"valY.npy")
    X_test=np.load(DATASETNAME+"testX.npy")
    y_test=np.load(DATASETNAME+"testY.npy")
    print("Loaded Files")
else:
    pass
# Out:
# Loaded Files

# %%
# y matrix structure
#(Fx-nondim, PressureField1,...,PressureField10,VelocityXField1,...,VelocityXField10,Px,Py,Pz,TauX,TauY,Tauz,AvgFx-NonDim-Per_Re_SF,Mask)
#Currently Mask is all ones.
print("Shape of Training and Testing Files")
print(X_train.shape,y_train.shape,X_val.shape,y_val.shape,X_test.shape,y_test.shape)
# Out:
# Shape of Training and Testing Files
# (2639, 47) (2639, 29) (564, 47) (564, 29) (2621, 47) (2621, 29)

# %% [markdown]
# ## Normalization

# %%
#Mask specifically for pressure and velocity fields.
mask_train=np.int32(y_train[:,-1])
mask_val=np.int32(y_val[:,-1])
mask_test=np.int32(y_test[:,-1])

# normalize on training set and apply to test set
std_scaler_x = StandardScaler()
std_scaler_y = StandardScaler()
std_scaler_pres=StandardScaler()
std_scaler_vel=StandardScaler()
std_scaler_presdragcomponents=StandardScaler()
std_scaler_veldragcomponents=StandardScaler()

# fit and transform on training set
X_train = std_scaler_x.fit_transform(X_train)
y_train[:, 0] = std_scaler_y.fit_transform(
    np.reshape(y_train[:, 0], (y_train.shape[0], 1))
)[:, 0]
  
#apply transformation on validation set.
X_val = std_scaler_x.transform(X_val)
y_val[:,0] = std_scaler_y.transform(
     np.reshape(y_val[:,0], (y_val.shape[0],1))
   )[:,0]

# apply transformation on test set
X_test = std_scaler_x.transform(X_test)
y_test[:, 0] = std_scaler_y.transform(
    np.reshape(y_test[:, 0], (y_test.shape[0], 1))
)[:, 0]

# # # #Standard Scaling of pressure y values. Only calculated for training.

y_train[mask_train==1,1:11] = std_scaler_pres.fit_transform(y_train[mask_train==1,1:11])
y_val[mask_val==1,1:11] = std_scaler_pres.transform(y_val[mask_val==1,1:11])
y_test[mask_test==1,1:11] = std_scaler_pres.transform(y_test[mask_test==1,1:11])


#### Standard Scaling of velocity y values.Only calculated for training.

y_train[mask_train==1,11:21] = std_scaler_vel.fit_transform(y_train[mask_train==1,11:21])
y_val[mask_val==1,11:21] = std_scaler_vel.transform(y_val[mask_val==1,11:21]) 
y_test[mask_test==1,11:21] = std_scaler_vel.transform(y_test[mask_test==1,11:21])

##### Standard Scaling Of Pressure Drag Components.

y_train[:,21:22] = std_scaler_presdragcomponents.fit_transform(y_train[:,21:22])
y_val[:,21:22] = std_scaler_presdragcomponents.transform(y_val[:,21:22])
y_test[:,21:22] = std_scaler_presdragcomponents.transform(y_test[:,21:22])


###### Standard Scaling of Velocity Drag Components.

y_train[:,24:25] = std_scaler_veldragcomponents.fit_transform(y_train[:,24:25])
y_val[:,24:25] = std_scaler_veldragcomponents.transform(y_val[:,24:25])
y_test[:,24:25] = std_scaler_veldragcomponents.transform(y_test[:,24:25])

print("Shapes y_train = {}, y_val = {}, y_test = {}".format(y_train.shape,y_val.shape,y_test.shape))
# Out:
# Shapes y_train = (2639, 29), y_val = (564, 29), y_test = (2621, 29)

# %% [markdown]
# # Create A Separate Y_pdfmeans Numpy Array To Explicitly Constrain Distribution Means Of Pressure Field Values and Velocity Field Values

# %%
re_train=X_train[:,-2]
sf_train=X_train[:,-1]
tmppres=y_train[:,1:11]
tmpvel=y_train[:,11:21]
_tmp=np.hstack([re_train[:,None],sf_train[:,None],tmppres,tmpvel])
columns=["Re","Solidfraction"]+["Pressure_X_{}".format(i+1) for i in range(10)]+["Velocity_X_{}".format(i+1) for i in range(10)]
_tmpdftrain=pd.DataFrame(_tmp,columns=columns)

prescols=["Pressure_X_{}".format(i+1) for i in range(10)]
velcols=["Velocity_X_{}".format(i+1) for i in range(10)]
pdf_means=dict()
pdf_meansvel=dict()
for key,val in _tmpdftrain.groupby(['Re','Solidfraction']):
    pdf_means[key]=val[prescols].mean().mean()
    pdf_meansvel[key]=val[velcols].mean().mean()
    

y_pdfmean=list()
for row in _tmpdftrain.iterrows():
    _re=row[1][0]
    _sf=row[1][1]
    y_pdfmean.append([pdf_means[(_re,_sf)],pdf_meansvel[(_re,_sf)]])
y_pdfmean = np.array(y_pdfmean)
print(y_pdfmean.shape)
# Out:
# (2639, 2)

# %% [markdown]
# # Fully Connected Network

# %% [markdown]
# ## Configurations

# %%
# CUDA support 
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# model settings
D_in  = X_train.shape[1]
output_size = 1    #1 FX-nondim value.
output_size_aux1 = 10  #10 Pressure Sampled values.
output_size_aux2 = 10  #10 Velocity X sampled values.
output_size_pdrag = 1
output_size_vdrag = 1

H = 128
depth = 4
depth_aux = 1
shared_depth = 1
NUMEPOCHS = 500
Batch_size = 100

# %% [markdown]
# ## Model

# %% [markdown]
# ## Training

# %%
models=[]

for parampres in [0.01,0.001,0.0001]:
    for paramvel in [0.1,0.01,0.001]:
        for paramdrag in [0.01]:
            test_mses=list()
            test_mres=list()
            test_preds_all=list()
            test_targets_all=list()
            best_model=None
            val_epochs=100
            seed_everything(123)


            param1=parampres
            param2=paramvel
            parampdrag=paramdrag
            paramvdrag=paramdrag
            parampdfpresmean=1.0
            parampdfvelmean=1.0
            
            hyperparameters={'presParam':param1,'velParam':param2,'PDrag':parampdrag,'VDrag':paramvdrag,
                      'parampdfpresmean':parampdfpresmean,'parampdfvelmean':parampdfvelmean}

            
            losses=list()
            # Compile model   
            model = MTNNConv_PressureVelocity(D_in, H, output_size,
                        output_size_aux1,output_size_aux2,output_size_pdrag,output_size_vdrag, 
                                              depth,depth_aux,shared_depth,device=device,
                                              numpresdragcomponent=1,numsheardragcomponent=1).to(device)

            # Loss Function
            criterion = torch.nn.MSELoss() 

            # Optimizer
            optimizer = optim.Adadelta(model.parameters())

            # Input Data
            trainX = Variable(torch.from_numpy(X_train).float()).to(device)
            trainY = Variable(torch.from_numpy(y_train[:,0]).float()).to(device)
            trainMask=torch.FloatTensor(torch.from_numpy(y_train[:,-1]).float()).to(device)
            
            trainY_AUX1 = Variable(torch.from_numpy(y_train[:,1:11]).float()).to(device)
            trainY_AUX2 = Variable(torch.from_numpy(y_train[:,11:21]).float()).to(device)
            
            trainY_PDrag = Variable(torch.from_numpy(y_train[:,21][:,None]).float()).to(device)
            trainY_VDrag = Variable(torch.from_numpy(y_train[:,24][:,None]).float()).to(device)
            
            trainY_PDFPRESMEANS = Variable(torch.from_numpy(y_pdfmean[:,0]).float()).to(device)
            trainY_PDFVELMEANS = Variable(torch.from_numpy(y_pdfmean[:,1]).float()).to(device) 

            valX = Variable(torch.from_numpy(X_val).float()).to(device)
            valY = Variable(torch.from_numpy(y_val[:,0]).float()).to(device)
            
            valMask=torch.FloatTensor(torch.from_numpy(y_val[:,-1]).float()).to(device)
            
            valY_AUX1 = Variable(torch.from_numpy(y_val[:,1:11]).float()).to(device)
            valY_AUX2 = Variable(torch.from_numpy(y_val[:,11:21]).float()).to(device)
            
            valY_PDrag = Variable(torch.from_numpy(y_val[:,21][:,None]).float()).to(device)
            valY_VDrag = Variable(torch.from_numpy(y_val[:,24][:,None]).float()).to(device)

            testX = Variable(torch.from_numpy(X_test).float()).to(device)
            testY = Variable(torch.from_numpy(y_test[:,0]).float()).to(device)
            
            testMask=torch.FloatTensor(torch.from_numpy(y_test[:,-1]).float()).to(device)
            
            testY_AUX1 = Variable(torch.from_numpy(y_test[:,1:11]).float()).to(device)
            testY_AUX2 = Variable(torch.from_numpy(y_test[:,11:21]).float()).to(device)
            
            testY_PDrag = Variable(torch.from_numpy(y_test[:,21][:,None]).float()).to(device)
            testY_VDrag = Variable(torch.from_numpy(y_test[:,24][:,None]).float()).to(device)

            # Train the model
            data_train_loader = DataLoader(
                list(zip(trainX,trainY,trainY_AUX1,trainY_AUX2,trainY_PDrag,trainY_VDrag,trainMask,trainY_PDFPRESMEANS,
                         trainY_PDFVELMEANS)), 
                batch_size=Batch_size, 
                shuffle=True)
            
            data_val_loader = DataLoader(list(zip(valX,valY,valY_AUX1,valY_AUX2,valY_PDrag,valY_VDrag,valMask)),
                                batch_size=Batch_size,shuffle=True)
            
            #Start Training
            for epoch in range(NUMEPOCHS):
                alltargets = list()
                allpredictions = list()
                allpredictions_aux_pres=list()
                allpredictions_aux_vel=list()
                allpredictions_pdrag=list()
                allpredictions_vdrag=list()

                epoch_losses_all=list()
                epoch_losses_main=list()
                epoch_losses_aux1=list()
                epoch_losses_aux2=list()
                epoch_losses_pdrag=list()
                epoch_losses_vdrag=list()

                for batchX, batchY,batchY_AUX_PRES,batchY_AUX_VEL,batchY_PDrag,batchY_VDrag,batchMask,batchY_PDFPRESMEAN,batchY_PDFVELMEAN in data_train_loader:

                    # Forward pass
                    outputs,outputs_AUX_PRES,outputs_AUX_VEL,outputs_Pdrag,outputs_Vdrag = model(batchX)

                    outputs_AUX_PRES=outputs_AUX_PRES*batchMask.unsqueeze(1)
                    outputs_AUX_VEL=outputs_AUX_VEL*batchMask.unsqueeze(1)

                    loss1 = criterion(outputs.squeeze(), batchY)
                    pres_loss = criterion(outputs_AUX_PRES,batchY_AUX_PRES)
                    vel_loss = criterion(outputs_AUX_VEL,batchY_AUX_VEL)
                    pdrag_loss = criterion(outputs_Pdrag,batchY_PDrag)
                    vdrag_loss = criterion(outputs_Vdrag,batchY_VDrag)
                    pdfpresmean_loss = criterion(outputs_AUX_PRES.mean(dim=1),batchY_PDFPRESMEAN.squeeze())
                    pdfvelmean_loss = criterion(outputs_AUX_VEL.mean(dim=1),batchY_PDFVELMEAN.squeeze())

                    loss = loss1 + param1*pres_loss + param2*vel_loss + parampdrag*pdrag_loss + paramvdrag*vdrag_loss + parampdfpresmean*pdfpresmean_loss + parampdfvelmean*pdfvelmean_loss

                    allpredictions_aux_pres.append(outputs_AUX_PRES)
                    allpredictions_aux_vel.append(outputs_AUX_VEL)
                    allpredictions.append(outputs)
                    alltargets.append(batchY)
                    allpredictions_pdrag.append(outputs_Pdrag)
                    allpredictions_vdrag.append(outputs_Vdrag)

                    # Backward and optimize
                    optimizer.zero_grad()
                    loss.backward()     
                    optimizer.step()
                    losses.append(loss)
                    epoch_losses_all.append(loss.item())
                    epoch_losses_main.append(loss1.item())
                    epoch_losses_aux1.append(pres_loss.item())
                    epoch_losses_aux2.append(vel_loss.item())
                    epoch_losses_pdrag.append(pdrag_loss.item())
                    epoch_losses_vdrag.append(vdrag_loss.item())

                if epoch%50==0:
                    print("Epoch = {}".format(epoch))

            #Validate For Parameter Tuning
            with torch.no_grad():
                outputsVal,outputsVal_AUX_PRES,outputsVal_AUX_VEL,outputsVal_Pdrag,outputsVal_Vdrag = model(valX)
                lossVal = criterion(outputsVal.squeeze(),valY)
                print("Loss Val = {}".format(lossVal.item()))
                preds=std_scaler_y.inverse_transform(outputsVal.cpu().data.numpy().squeeze())
                tgts=std_scaler_y.inverse_transform(valY.cpu().data.numpy().squeeze())

                mse = np.mean(np.square(preds - tgts))
                rel_err = np.mean(np.abs(preds - tgts)/y_val[:,-2])
                aurec = ev_viz.aurec(preds,tgts,y_val[:,-2])
                
                performance={'val_mse':mse,'val_re':rel_err,'val_aurec':aurec}

            #Update Settings Dict.
            settings=dict()
            settings['hyperparameters']=hyperparameters
            settings['performance'] = performance
            settings['model'] = model
            
            models.append(settings)
            
            print('\nTraining Complete')
# Out:
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.09129443764686584
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.08152724802494049
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.0755411833524704
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.0818059965968132
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.0896904394030571
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.0881105363368988
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.08657997101545334
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.08848527073860168
#
# Training Complete
# Hidden Conv Size = 8
# Epoch = 0
# Epoch = 50
# Epoch = 100
# Epoch = 150
# Epoch = 200
# Epoch = 250
# Epoch = 300
# Epoch = 350
# Epoch = 400
# Epoch = 450
# Loss Val = 0.08981118351221085
#
# Training Complete

# %%
#Get Best Model for each of (MSE,MRE,AUREC). We use Best AUREC model for all our evaluation results.
best_model_mse=None
best_model_mre=None
best_model_aurec=None
best_mse=-np.inf
best_mre=-np.inf
best_aurec=-np.inf
for idx,m in enumerate(models):
    hyp=m['hyperparameters']
    perf=m['performance']
    if perf['val_mse']>best_mse:
        print("Best MSE Idx=  {}".format(idx))
        best_mse=perf['val_mse']
        best_model_mse=m['model']
        
    if perf['val_re']>best_mre:
        print("Best MRE Idx = {}".format(idx))
        best_mre=perf['val_re']
        best_model_mre=m['model']
    
    if perf['val_aurec']>best_aurec:
        print("Best AUREC Idx = {}".format(idx))
        best_aurec=perf['val_aurec']
        best_model_aurec=m['model']
    

    print("Hyper Parameters = {}".format(hyp))
    print("Performance = {}".format(perf))
    print("===========================================\n\n")
# Out:
# Best MSE Idx=  0
# Best MRE Idx = 0
# Best AUREC Idx = 0
# Hyper Parameters = {'presParam': 0.01, 'velParam': 0.1, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 17.454752, 'val_re': 0.19410423482772038, 'val_aurec': 0.8278812056737589}
# ===========================================
#
#
# Best AUREC Idx = 1
# Hyper Parameters = {'presParam': 0.01, 'velParam': 0.01, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 15.587347, 'val_re': 0.15263493594771524, 'val_aurec': 0.86072695035461}
# ===========================================
#
#
# Best AUREC Idx = 2
# Hyper Parameters = {'presParam': 0.01, 'velParam': 0.001, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 14.442861, 'val_re': 0.14259675673891795, 'val_aurec': 0.8711879432624112}
# ===========================================
#
#
# Hyper Parameters = {'presParam': 0.001, 'velParam': 0.1, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 15.640639, 'val_re': 0.15838782145039887, 'val_aurec': 0.8553191489361701}
# ===========================================
#
#
# Hyper Parameters = {'presParam': 0.001, 'velParam': 0.01, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 17.148083, 'val_re': 0.19167936925880202, 'val_aurec': 0.8289893617021278}
# ===========================================
#
#
# Best AUREC Idx = 5
# Hyper Parameters = {'presParam': 0.001, 'velParam': 0.001, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 16.846018, 'val_re': 0.13316764634927494, 'val_aurec': 0.8791666666666668}
# ===========================================
#
#
# Hyper Parameters = {'presParam': 0.0001, 'velParam': 0.1, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 16.553387, 'val_re': 0.14157513141491038, 'val_aurec': 0.8703900709219858}
# ===========================================
#
#
# Hyper Parameters = {'presParam': 0.0001, 'velParam': 0.01, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 16.917667, 'val_re': 0.14372120451912238, 'val_aurec': 0.869636524822695}
# ===========================================
#
#
# Hyper Parameters = {'presParam': 0.0001, 'velParam': 0.001, 'PDrag': 0.01, 'VDrag': 0.01, 'parampdfpresmean': 1.0, 'parampdfvelmean': 1.0}
# Performance = {'val_mse': 17.171167, 'val_re': 0.14856980546347417, 'val_aurec': 0.8645390070921988}
# ===========================================

# %%
model=best_model_aurec
 
auxiliary_predictions_pressure=list()
auxiliary_predictions_velocity=list()
with torch.no_grad():
    testpreds,testpreds_aux_pres,testpreds_aux_vel,outputsPDrag,outputsVDrag = model(testX)
    preds = torch.from_numpy(
        std_scaler_y.inverse_transform(testpreds.cpu().detach().squeeze())
    ).float()

    re=std_scaler_x.inverse_transform(testX.to("cpu").data.numpy())[:,-2]
    sf=std_scaler_x.inverse_transform(testX.to("cpu").data.numpy())[:,-1]

    tgts = torch.from_numpy(
        std_scaler_y.inverse_transform(testY.cpu().data.numpy().squeeze())
    ).float()
    
    error = np.mean(np.square(preds.squeeze().data.numpy() - tgts.squeeze().data.numpy()))
    #print("Parameter setting p1 = {}, p2 = {}, p3 = {}".format(p1,p2,p3))
    print("Test MSE = {}".format(error))

    #Relative Error
    rel_err=np.mean(np.abs(preds.squeeze().data.cpu().numpy() - tgts.squeeze().data.cpu().numpy())/y_test[:,-2])
    print("Relative Error = {}".format(rel_err))

    mape_err=100*np.mean(np.abs((preds.squeeze().data.cpu().numpy() - tgts.squeeze().data.cpu().numpy())/tgts.squeeze().data.cpu().numpy()))
    print("Mean Abs. Percentage Error = {}".format(mape_err))
    
    aurec=ev_viz.aurec(preds.squeeze().data.cpu().numpy(),tgts.squeeze().data.cpu().numpy(),y_test[:,-2])
    print("AUREC = {}".format(aurec))
    print("===============================================================\n")

##################### SAVE Model and Predictions AUREC ############################
#SAVE Model and Predictions AUREC
MODEL='PhyDNNPxTx-PDFPRESMEAN-{}-PDFVELMEAN-{}-PX-TauX'.format(parampdfpresmean,parampdfvelmean)
_tmp=std_scaler_x.inverse_transform(X_test)
preds_pres=std_scaler_pres.inverse_transform(testpreds_aux_pres.cpu().data.numpy())
preds_vel=std_scaler_vel.inverse_transform(testpreds_aux_vel.cpu().data.numpy())
act_pres=std_scaler_pres.inverse_transform(testY_AUX1.cpu().data.numpy())
act_vel=std_scaler_vel.inverse_transform(testY_AUX2.cpu().data.numpy())
preds_pdrag=std_scaler_presdragcomponents.inverse_transform(outputsPDrag.cpu().data.numpy())
preds_vdrag=std_scaler_veldragcomponents.inverse_transform(outputsVDrag.cpu().data.numpy())
act_pdrag=std_scaler_presdragcomponents.inverse_transform(testY_PDrag.cpu().data.numpy())
act_vdrag=std_scaler_veldragcomponents.inverse_transform(testY_VDrag.cpu().data.numpy())

_tmp2=np.hstack([preds.to("cpu").data.numpy().ravel()[:,None],
                 tgts.to("cpu").data.numpy().ravel()[:,None],
                 y_test[:,-2].squeeze()[:,None],
                 _tmp[:,-2].squeeze()[:,None],
                 _tmp[:,-1].squeeze()[:,None],
                 preds_pres,preds_vel,act_pres,act_vel,preds_pdrag,preds_vdrag,act_pdrag,act_vdrag])


pres_cols=['PressurePredictions_{}'.format(i+1) for i in range(10)]
vel_cols=['VelocityPredictions_{}'.format(i+1) for i in range(10)]
pres_act_cols=['PressureActual_{}'.format(i+1) for i in range(10)]
vel_act_cols=['VelocityActual_{}'.format(i+1) for i in range(10)]
pdrag_pred_cols=['Px_Predictions']
vdrag_pred_cols=['Taux_Predictions']
pdrag_act_cols=['Px']
vdrag_act_cols=['Taux']

_df=pd.DataFrame(_tmp2,columns=['{}-Predictions'.format(MODEL),'Targets','Mean','Re','Solidfraction']+\
                 pres_cols+vel_cols+pres_act_cols+vel_act_cols+pdrag_pred_cols+vdrag_pred_cols+pdrag_act_cols+vdrag_act_cols)


#Structure of output predictions dataframe: 
"""
[  Fx-Nondim_Prediction,
   Fx-Nondim_Target,
   Mean_Per_Re_Sf,
   Re,
   Sf,
   pressurepred1,
   ...
   pressurepred10,
   velpred1,
   ...
   velpred10,
   pressureactual1,
   ...
   pressureactual10,
   velactual1,
   ...
   velactual10,
   Px_pred,
   TauX_pred,
   Px_Actual,
   TauX_Actual
]

"""
outputfile="/home/nik90/experiments/particleDragForce/dnn_mt_seq/{}_case1_predictions_TRAINPERCENTAGE_{}.csv".format(MODEL,TRAINPERCENTAGE)
_df.to_csv(outputfile,index=False)
#Save Model
torch.save(model.state_dict(),"../../../../models/Nikhil_{}_Case1_TrainPercentage_{}".format(MODEL,TRAINPERCENTAGE))


    
model=best_model_mre
# Test MSE (un_normalized) 
auxiliary_predictions_pressure=list()
auxiliary_predictions_velocity=list()
with torch.no_grad():
    testpreds,testpreds_aux_pres,testpreds_aux_vel,_,_ = model(testX)
    preds = torch.from_numpy(
        std_scaler_y.inverse_transform(testpreds.cpu().detach().squeeze())
    ).float()

    re=std_scaler_x.inverse_transform(testX.to("cpu").data.numpy())[:,-2]
    sf=std_scaler_x.inverse_transform(testX.to("cpu").data.numpy())[:,-1]

    tgts = torch.from_numpy(
        std_scaler_y.inverse_transform(testY.cpu().data.numpy().squeeze())
    ).float()

    auxiliary_predictions_pressure = std_scaler_pres.inverse_transform(testpreds_aux_pres.to("cpu").data.numpy())
    auxiliary_predictions_velocity = std_scaler_vel.inverse_transform(testpreds_aux_vel.to("cpu").data.numpy())

    error = np.mean(np.square(preds.squeeze().data.numpy() - tgts.squeeze().data.numpy()))
    #print("Parameter setting p1 = {}, p2 = {}, p3 = {}".format(p1,p2,p3))
    print("Test MSE = {}".format(error))

    #Relative Error
    rel_err=np.mean(np.abs(preds.squeeze().data.cpu().numpy() - tgts.squeeze().data.cpu().numpy())/y_test[:,-2])
    print("Relative Error = {}".format(rel_err))

    mape_err=100*np.mean(np.abs((preds.squeeze().data.cpu().numpy() - tgts.squeeze().data.cpu().numpy())/tgts.squeeze().data.cpu().numpy()))
    print("Mean Abs. Percentage Error = {}".format(mape_err))
    
    
    aurec=ev_viz.aurec(preds.squeeze().data.cpu().numpy(),tgts.squeeze().data.cpu().numpy(),y_test[:,-2])
    print("AUREC = {}".format(aurec))
    print("===============================================================\n")

    
model=best_model_mse
# Test MSE (un_normalized) 
auxiliary_predictions_pressure=list()
auxiliary_predictions_velocity=list()
with torch.no_grad():
    testpreds,testpreds_aux_pres,testpreds_aux_vel,_,_ = model(testX)
    preds = torch.from_numpy(
        std_scaler_y.inverse_transform(testpreds.cpu().detach().squeeze())
    ).float()

    re=std_scaler_x.inverse_transform(testX.to("cpu").data.numpy())[:,-2]
    sf=std_scaler_x.inverse_transform(testX.to("cpu").data.numpy())[:,-1]

    tgts = torch.from_numpy(
        std_scaler_y.inverse_transform(testY.cpu().data.numpy().squeeze())
    ).float()

    auxiliary_predictions_pressure = std_scaler_pres.inverse_transform(testpreds_aux_pres.to("cpu").data.numpy())
    auxiliary_predictions_velocity = std_scaler_vel.inverse_transform(testpreds_aux_vel.to("cpu").data.numpy())

    error = np.mean(np.square(preds.squeeze().data.numpy() - tgts.squeeze().data.numpy()))
    #print("Parameter setting p1 = {}, p2 = {}, p3 = {}".format(p1,p2,p3))
    print("Test MSE = {}".format(error))

    #Relative Error
    rel_err=np.mean(np.abs(preds.squeeze().data.cpu().numpy() - tgts.squeeze().data.cpu().numpy())/y_test[:,-2])
    print("Relative Error = {}".format(rel_err))

    mape_err=100*np.mean(np.abs((preds.squeeze().data.cpu().numpy() - tgts.squeeze().data.cpu().numpy())/tgts.squeeze().data.cpu().numpy()))
    print("Mean Abs. Percentage Error = {}".format(mape_err))
    
    aurec=ev_viz.aurec(preds.squeeze().data.cpu().numpy(),tgts.squeeze().data.cpu().numpy(),y_test[:,-2])
    print("AUREC = {}".format(aurec))
    print("===============================================================\n")
# Out:
# Test MSE = 15.537384033203125
# Relative Error = 0.14060902465356112
# Mean Abs. Percentage Error = 15.25636911392212
# AUREC = 0.8723197252956887
# ===============================================================
#
# --Return--
# > <ipython-input-15-697b612633e7>(53)<module>()->None
# -> pdb.set_trace()
# (Pdb) c
# Test MSE = 18.74254035949707
# Relative Error = 0.20402658536633697
# Mean Abs. Percentage Error = 22.6811945438385
# AUREC = 0.8159481114078595
# ===============================================================
#
# Test MSE = 18.74254035949707
# Relative Error = 0.20402658536633697
# Mean Abs. Percentage Error = 22.6811945438385
# AUREC = 0.8159481114078595
# ===============================================================

# %% [markdown]
# # Ignore Everything After This Cell

# %% [markdown]
# # Standard AE

# %%
class AE(nn.Module):
    def __init__(self,input_size=12,hidden_size=128,conv_filter_size=3,latent_size=20):
        super(AE,self).__init__()
        output_size = input_size
        self.hidden_size_conv = ((output_size - conv_filter_size)//1) + 1

#         self.c1= torch.nn.Conv1d(in_channels=1,out_channels=1, kernel_size=conv_filter_size)
#         self.pool1= torch.nn.MaxPool1d(kernel_size=min(2,self.hidden_size_conv),padding=0)
        
        self.fc1 = torch.nn.Linear(input_size,hidden_size)
        self.fc2 = torch.nn.Linear(hidden_size,hidden_size)
        self.fc3 = torch.nn.Linear(hidden_size,hidden_size)
        self.fc4 = torch.nn.Linear(hidden_size,hidden_size)
        self.fc5 = torch.nn.Linear(hidden_size,hidden_size)
        self.fc6 = torch.nn.Linear(hidden_size,hidden_size)
        self.fc7 = torch.nn.Linear(hidden_size,latent_size)

        self.elu = torch.nn.ELU()
                    
#         self.dc1 = nn.ConvTranspose1d(in_channels=1,out_channels=1,kernel_size=conv_filter_size)
#         self.pool2=torch.nn.MaxPool1d(kernel_size=min(2,self.hidden_size_conv),padding=0)
        self.cf7 = torch.nn.Linear(latent_size,hidden_size)
        self.cf6 = torch.nn.Linear(hidden_size,hidden_size)
        self.cf5 = torch.nn.Linear(hidden_size,hidden_size)
        self.cf4 = torch.nn.Linear(hidden_size,hidden_size)
        self.cf3 = torch.nn.Linear(hidden_size,hidden_size)
        self.cf2 = torch.nn.Linear(hidden_size,hidden_size)
        self.cf1 = torch.nn.Linear(hidden_size,output_size)

        
    def forward(self,x):
        out = self.elu(self.fc1(x))
        out = self.elu(self.fc2(out))
        out = self.elu(self.fc3(out))
        out = self.elu(self.fc4(out))
        out = self.elu(self.fc5(out))
        out = self.elu(self.fc6(out))
        z   = self.elu(self.fc7(out))
        
        out = self.elu(self.cf7(z))
        out = self.elu(self.cf6(out))
        out = self.elu(self.cf5(out))
        out = self.elu(self.cf4(out))
        out = self.elu(self.cf3(out))
        out = self.elu(self.cf2(out))
        out = self.elu(self.cf1(out))
        
        return out

# %%
model = AE()
if torch.cuda.is_available():
    model.cuda()

reconstruction_function = nn.MSELoss(size_average=False)

re_train=X_train[:,-2][:,None]
sf_train=X_train[:,-1][:,None]
re_test=X_test[:,-2][:,None]
sf_test=X_test[:,-1][:,None]

trainY_AUX1 = Variable(torch.from_numpy(np.hstack([y_train[:,1:11],re_train,sf_train])).float()).to(device)
testY_AUX1 = Variable(torch.from_numpy(np.hstack([y_test[:,1:11],re_test,sf_test])).float()).to(device)

dataloader = DataLoader(trainY_AUX1, batch_size=batch_size, shuffle=True)
dataloader_test= DataLoader(testY_AUX1, batch_size=batch_size, shuffle=True)

# with torch.no_grad():
#     dataloader_test = DataLoader(testY_AUX1, batch_size=batch_size, shuffle=True)
#     preds=list()
#     for batch_idx, data in enumerate(dataloader_test):
#         recon_batch,_,_ = model(data.to(device))
#         preds.append(recon_batch)
    
#     preds=torch.cat(preds)
#     print(preds.size())

def loss_function(recon_x, x):
    """
    recon_x: generating images
    x: origin images
    """
    mse = reconstruction_function(recon_x, x)  # mse loss
    # KL divergence
    return mse


optimizer = optim.Adam(model.parameters(), lr=1e-3)
losses=list()
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    for batch_idx, data in enumerate(dataloader):
        img = data
        img = Variable(img)
        if torch.cuda.is_available():
            img = img.cuda()
        optimizer.zero_grad()
        recon_batch = model(img)
        loss = loss_function(recon_batch, img)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
#         if batch_idx % 100 == 0:
#             print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
#                 epoch,
#                 batch_idx * len(img),
#                 len(dataloader.dataset), 100. * batch_idx / len(dataloader),
#                 loss.item() / len(img)))
    losses.append(train_loss)
    print('====> Epoch: {} Average loss: {:.4f}'.format(
        epoch, train_loss / len(dataloader.dataset)))
#     if epoch % 10 == 0:
#         save = to_img(recon_batch.cpu().data)
#         save_image(save, data_out_dir+'/{}/image_{}.png'.format(output_predictions,epoch))

torch.save(model.state_dict(), '../models/ae.pth')
plt.plot(losses)
# Out:
# /home/nik90/anaconda3/lib/python3.7/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# ====> Epoch: 465 Average loss: 0.5361
# ====> Epoch: 466 Average loss: 0.5499
# ====> Epoch: 467 Average loss: 0.5566
# ====> Epoch: 468 Average loss: 0.5533
# ====> Epoch: 469 Average loss: 0.5412
# ====> Epoch: 470 Average loss: 0.5381
# ====> Epoch: 471 Average loss: 0.5273
# ====> Epoch: 472 Average loss: 0.5236
# ====> Epoch: 473 Average loss: 0.5211
# ====> Epoch: 474 Average loss: 0.5203
# ====> Epoch: 475 Average loss: 0.5185
# ====> Epoch: 476 Average loss: 0.5187
# ====> Epoch: 477 Average loss: 0.5192
# ====> Epoch: 478 Average loss: 0.5209
# ====> Epoch: 479 Average loss: 0.5225
# ====> Epoch: 480 Average loss: 0.5412
# ====> Epoch: 481 Average loss: 0.5490
# ====> Epoch: 482 Average loss: 0.5580
# ====> Epoch: 483 Average loss: 0.5333
# ====> Epoch: 484 Average loss: 0.5281
# ====> Epoch: 485 Average loss: 0.5288
# ====> Epoch: 486 Average loss: 0.5311
# ====> Epoch: 487 Average loss: 0.5273
# ====> Epoch: 488 Average loss: 0.5238
# ====> Epoch: 489 Average loss: 0.5187
# ====> Epoch: 490 Average loss: 0.5178
# ====> Epoch: 491 Average loss: 0.5185
# ====> Epoch: 492 Average loss: 0.5178
# ====> Epoch: 493 Average loss: 0.5196
# ====> Epoch: 494 Average loss: 0.5198
# ====> Epoch: 495 Average loss: 0.5182
# ====> Epoch: 496 Average loss: 0.5289
# ====> Epoch: 497 Average loss: 0.5381
# ====> Epoch: 498 Average loss: 0.5418
# ====> Epoch: 499 Average loss: 0.5501

# %%
with torch.no_grad():
    dataloader_test = DataLoader(testY_AUX1, batch_size=batch_size, shuffle=True)
    preds=list()
    for batch_idx, data in enumerate(dataloader_test):
        recon_batch= model(data.to(device))
        preds.append(recon_batch[:,:-2])
    
    preds=torch.cat(preds)
    print(preds.size())
# Out:
# torch.Size([2621, 10])

# %%
re_test=X_test[:,-2]
sf_test=X_test[:,-1]
tmppres=std_scaler_pres.inverse_transform(preds.to("cpu").data.numpy())
tmpvel=y_test[:,11:21]
_tmp=np.hstack([re_test[:,None],sf_test[:,None],tmppres,tmpvel])
columns=["Re","Solidfraction"]+["Pressure_X_{}".format(i+1) for i in range(10)]+["Velocity_X_{}".format(i+1) for i in range(10)]
_tmpdftrain=pd.DataFrame(_tmp,columns=columns)

fig,ax=plt.subplots(1,1,figsize=(12,8))
legend=[]
colors=['r','g','b','c','m','k','w','y']
for idx,(key,val) in enumerate(_tmpdftrain.groupby(['Re','Solidfraction'])):
    _ax=sns.kdeplot(val[['Pressure_X_{}'.format(i+1) for i in range(10)]].values.ravel(),label='',c=colors[idx%len(colors)])
    legend.append("RE{}_SF{}".format(round(key[0],2),round(key[1],2))) 

[line.set_linestyle("--") if idx>7 else line.set_linestyle('-') for idx,line in enumerate(ax.lines)]
ax.legend(legend)
# Out:
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
# /home/nik90/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1725: UserWarning: Saw kwargs ['c', 'color'] which are all aliases for 'color'.  Kept value from 'color'
#   seen=seen, canon=canonical, used=seen[-1]))
